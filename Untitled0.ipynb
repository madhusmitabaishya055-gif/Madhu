# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data ingestion
file_path = '/content/student_placement_1000_rows(student_placement_1000_rows).csv'

with open(file_path, 'r') as f:
  df = pd.read_csv(f)

# %%
df.head(6)
# Out:
#    Gender  SSC_Percentage  HSC_Percentage    Stream  Degree_Percentage  \
# 0    Male              51              67   Science                 69
# 1    Male              51              55   Science                 69
# 2  Female              87              67   Science                 65
# 3  Female              56              55  Commerce                 61
# 4  Female              84              57  Commerce                 60
# 5    Male              52              92   Science                 73
#
#   Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 0         BSc            0         4         1            8               7
# 1       BTech            4         1         5            7               5
# 2          BA            2         2         2            5              10
# 3        BCom            2         4         3           10               4
# 4        BCom            4         2         5            5               9
# 5       BTech            1         0         4            6               7
#
#   Placed
# 0     No
# 1     No
# 2     No
# 3     No
# 4     No
# 5    Yes

# %%
df.tail(10)
# Out:
#      Gender  SSC_Percentage  HSC_Percentage    Stream  Degree_Percentage  \
# 990    Male              75              50      Arts                 67
# 991    Male              88              78   Science                 88
# 992  Female              53              77  Commerce                 79
# 993    Male              68              69  Commerce                 73
# 994  Female              91              82   Science                 84
# 995  Female              69              72   Science                 55
# 996  Female              81              62   Science                 88
# 997  Female              64              80  Commerce                 78
# 998  Female              56              78      Arts                 83
# 999    Male              57              62  Commerce                 57
#
#     Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 990       BTech            3         4         3            5               9
# 991         BSc            1         0         3           10               5
# 992         BSc            2         0         3            9               5
# 993        BCom            1         0         5            7               5
# 994          BA            0         2         1            8               7
# 995        BCom            1         3         3            4               4
# 996         BSc            3         0         4            4               5
# 997        BCom            2         3         2            8              10
# 998         BSc            1         2         4            4               6
# 999         BSc            3         3         3            4               5
#
#     Placed
# 990     No
# 991     No
# 992     No
# 993     No
# 994     No
# 995     No
# 996     No
# 997     No
# 998     No
# 999     No

# %%
df.sample(12)
# Out:
#      Gender  SSC_Percentage  HSC_Percentage    Stream  Degree_Percentage  \
# 681    Male              70              72  Commerce                 87
# 759    Male              72              76      Arts                 90
# 697  Female              88              88      Arts                 58
# 941    Male              61              62  Commerce                 81
# 490  Female              81              61      Arts                 72
# 711    Male              76              79   Science                 62
# 147  Female              56              71      Arts                 60
# 561  Female              64              59  Commerce                 80
# 344    Male              71              95   Science                 75
# 20     Male              84              58      Arts                 85
# 647    Male              74              94  Commerce                 62
# 9      Male              66              58   Science                 90
#
#     Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 681          BA            2         0         1            6               6
# 759        BCom            3         0         1            9               9
# 697        BCom            3         1         4            6               7
# 941          BA            4         0         2            4               6
# 490          BA            1         4         2            4               8
# 711         BSc            0         3         3            6               9
# 147         BSc            0         1         4            7               8
# 561         BSc            0         3         5            9               8
# 344       BTech            0         1         5            9               5
# 20          BSc            3         3         2            4               4
# 647        BCom            2         2         4            4               9
# 9          BCom            4         3         5            7               6
#
#     Placed
# 681    Yes
# 759    Yes
# 697     No
# 941    Yes
# 490     No
# 711     No
# 147     No
# 561     No
# 344     No
# 20      No
# 647     No
# 9       No

# %%
df.shape[1]
# Out:
# 12

# %%
df.shape[0]
# Out:
# 1000

# %%
df.shape[1]
# Out:
# 12

# %%
#null values
df.isnull()
# Out:
#      Gender  SSC_Percentage  HSC_Percentage  Stream  Degree_Percentage  \
# 0     False           False           False   False              False
# 1     False           False           False   False              False
# 2     False           False           False   False              False
# 3     False           False           False   False              False
# 4     False           False           False   False              False
# ..      ...             ...             ...     ...                ...
# 995   False           False           False   False              False
# 996   False           False           False   False              False
# 997   False           False           False   False              False
# 998   False           False           False   False              False
# 999   False           False           False   False              False
#
#      Degree_Type  Internships  Backlogs  Projects  Soft_Skills  \
# 0          False        False     False     False        False
# 1          False        False     False     False        False
# 2          False        False     False     False        False
# 3          False        False     False     False        False
# 4          False        False     False     False        False
# ..           ...          ...       ...       ...          ...
# 995        False        False     False     False        False
# 996        False        False     False     False        False
# 997        False        False     False     False        False
# 998        False        False     False     False        False
# 999        False        False     False     False        False
#
#      Aptitude_Score  Placed
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# ..              ...     ...
# 995           False   False
# 996           False   False
# 997           False   False
# 998           False   False
# 999           False   False
#
# [1000 rows x 12 columns]

# %%
# agression function
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#duplicate value
df.duplicated() .sum()
# Out:
# np.int64(0)

# %%
df.Gender.value_counts().plot(kind='pie',
                              figsize=(5,5),
                              autopct= '%1.1f%%',
                              startangle=90, shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df[df['Gender']=='Female']['Placed'].value_counts().plot(kind='bar',
                              figsize=(5,5))
# Out:
# <Axes: xlabel='Placed'>

# %%
cat_cols = df.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['Gender', 'Stream', 'Degree_Type', 'Placed'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             1000 non-null   object
#  1   SSC_Percentage     1000 non-null   int64
#  2   HSC_Percentage     1000 non-null   int64
#  3   Stream             1000 non-null   object
#  4   Degree_Percentage  1000 non-null   int64
#  5   Degree_Type        1000 non-null   object
#  6   Internships        1000 non-null   int64
#  7   Backlogs           1000 non-null   int64
#  8   Projects           1000 non-null   int64
#  9   Soft_Skills        1000 non-null   int64
#  10  Aptitude_Score     1000 non-null   int64
#  11  Placed             1000 non-null   object
# dtypes: int64(8), object(4)
# memory usage: 93.9+ KB

# %%
num_cols = df.select_dtypes(include=['int64']).columns
num_cols
# Out:
# Index(['SSC_Percentage', 'HSC_Percentage', 'Degree_Percentage', 'Internships',
#        'Backlogs', 'Projects', 'Soft_Skills', 'Aptitude_Score'],
#       dtype='object')

# %%
#ssc_percentage
print("max percentage",df['SSC_Percentage'].max())
print("min percentage",df['SSC_Percentage'].min())
print("mean percentage",df['SSC_Percentage'].mean())
# Out:
# max percentage 95
# min percentage 50
# mean percentage 72.304

# %%
df[df['SSC_Percentage']==95]['Placed'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
cat_cols
# Out:
# Index(['Gender', 'Stream', 'Degree_Type', 'Placed'], dtype='object')

# %%
#transform
df.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995    Female
# 996    Female
# 997    Female
# 998    Female
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
#transform string into number/integer
from sklearn.preprocessing import OneHotEncoder,LabelEncoder, OrdinalEncoder


#create a object
ohe = OneHotEncoder(sparse_output=False,drop='first')

df['Gender'] = ohe.fit_transform(df[['Gender']])

# %%
df.Gender.value_counts()
# Out:
# Gender
# 1.0    527
# 0.0    473
# Name: count, dtype: int64

# %%
df['Stream'].value_counts()
# Out:
# Stream
# Science     339
# Arts        338
# Commerce    323
# Name: count, dtype: int64

# %%
df['Stream'] = ohe.fit_transform(df[['Stream']])

# %%
df['Degree_Type'].value_counts()
# Out:
# Degree_Type
# BA       268
# BSc      251
# BCom     244
# BTech    237
# Name: count, dtype: int64

# %%
df['Placed'].value_counts()
# Out:
# Placed
# 0.0    877
# 1.0    123
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    Gender  SSC_Percentage  HSC_Percentage  Stream  Degree_Percentage  \
# 0     1.0              51              67     0.0                 69
# 1     1.0              51              55     0.0                 69
#
#   Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 0         BSc            0         4         1            8               7
# 1       BTech            4         1         5            7               5
#
#    Placed
# 0     0.0
# 1     0.0

# %%
#Labelencoding
le = LabelEncoder()
df['Placed'] = le.fit_transform(df['Placed'])

# %%
df.head()
# Out:
#    Gender  SSC_Percentage  HSC_Percentage  Stream  Degree_Percentage  \
# 0     1.0              51              67     0.0                 69
# 1     1.0              51              55     0.0                 69
# 2     0.0              87              67     0.0                 65
# 3     0.0              56              55     1.0                 61
# 4     0.0              84              57     1.0                 60
#
#   Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 0         BSc            0         4         1            8               7
# 1       BTech            4         1         5            7               5
# 2          BA            2         2         2            5              10
# 3        BCom            2         4         3           10               4
# 4        BCom            4         2         5            5               9
#
#    Placed
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df
# Out:
#      Gender  SSC_Percentage  HSC_Percentage  Stream  Degree_Percentage  \
# 0       1.0              51              67     0.0                 69
# 1       1.0              51              55     0.0                 69
# 2       0.0              87              67     0.0                 65
# 3       0.0              56              55     1.0                 61
# 4       0.0              84              57     1.0                 60
# ..      ...             ...             ...     ...                ...
# 995     0.0              69              72     0.0                 55
# 996     0.0              81              62     0.0                 88
# 997     0.0              64              80     1.0                 78
# 998     0.0              56              78     0.0                 83
# 999     1.0              57              62     1.0                 57
#
#     Degree_Type  Internships  Backlogs  Projects  Soft_Skills  Aptitude_Score  \
# 0           BSc            0         4         1            8               7
# 1         BTech            4         1         5            7               5
# 2            BA            2         2         2            5              10
# 3          BCom            2         4         3           10               4
# 4          BCom            4         2         5            5               9
# ..          ...          ...       ...       ...          ...             ...
# 995        BCom            1         3         3            4               4
# 996         BSc            3         0         4            4               5
# 997        BCom            2         3         2            8              10
# 998         BSc            1         2         4            4               6
# 999         BSc            3         3         3            4               5
#
#      Placed
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 995       0
# 996       0
# 997       0
# 998       0
# 999       0
#
# [1000 rows x 12 columns]

# %%
df['Degree_Type'] = ohe.fit_transform(df[['Degree_Type']])

# %%
#data splitting
X = df.drop('Placed' ,axis=1)
Y = df['Placed']

# %%
df
# Out:
#      Gender  SSC_Percentage  HSC_Percentage  Stream  Degree_Percentage  \
# 0       1.0              51              67     0.0                 69
# 1       1.0              51              55     0.0                 69
# 2       0.0              87              67     0.0                 65
# 3       0.0              56              55     1.0                 61
# 4       0.0              84              57     1.0                 60
# ..      ...             ...             ...     ...                ...
# 995     0.0              69              72     0.0                 55
# 996     0.0              81              62     0.0                 88
# 997     0.0              64              80     1.0                 78
# 998     0.0              56              78     0.0                 83
# 999     1.0              57              62     1.0                 57
#
#      Degree_Type  Internships  Backlogs  Projects  Soft_Skills  \
# 0            0.0            0         4         1            8
# 1            0.0            4         1         5            7
# 2            0.0            2         2         2            5
# 3            1.0            2         4         3           10
# 4            1.0            4         2         5            5
# ..           ...          ...       ...       ...          ...
# 995          1.0            1         3         3            4
# 996          0.0            3         0         4            4
# 997          1.0            2         3         2            8
# 998          0.0            1         2         4            4
# 999          0.0            3         3         3            4
#
#      Aptitude_Score  Placed
# 0                 7       0
# 1                 5       0
# 2                10       0
# 3                 4       0
# 4                 9       0
# ..              ...     ...
# 995               4       0
# 996               5       0
# 997              10       0
# 998               6       0
# 999               5       0
#
# [1000 rows x 12 columns]

# %%
X.shape
# Out:
# (1000, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
X_train.shape
# Out:
# (800, 11)

# %%
# Model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)

# Predictions
y_pred = log_reg.predict(X_test)
y_prob = log_reg.predict_proba(X_test)[:, 1]

# Evaluation
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
# Out:
# Confusion Matrix:
#  [[170  11]
#  [  9  10]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       181
#            1       0.48      0.53      0.50        19
#
#     accuracy                           0.90       200
#    macro avg       0.71      0.73      0.72       200
# weighted avg       0.90      0.90      0.90       200
#
# ROC-AUC Score: 0.9110206455364931
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
